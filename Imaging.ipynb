# %%
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
nparr = np.array(pd.read_csv(r'./ImagingModel.csv',header = None))
print(nparr)
# Out:
# [[0.00376793 0.00402926 0.00471104 ... 0.00471104 0.00402926 0.00376793]
#  [0.00382102 0.00407679 0.00474491 ... 0.0047449  0.00407679 0.00382102]
#  [0.00397711 0.00421678 0.00484531 ... 0.0048453  0.00421677 0.00397711]
#  ...
#  [0.00397711 0.00421678 0.0048453  ... 0.00484531 0.00421678 0.00397711]
#  [0.00382102 0.00407679 0.0047449  ... 0.00474491 0.00407679 0.00382102]
#  [0.00376793 0.00402926 0.00471104 ... 0.00471104 0.00402926 0.00376793]]

# %%
plt.figure(figsize=(10,7))# 定义输出图像大小，annot参数决定是否在热力图上显示数值，Vmax,Vmin表示最大最小值，cmap表示颜色
i=0

sns.heatmap(nparr,
            cmap = 'viridis')
# plt.plot(nparr)
# # fmt='.0f', annot=True, vmin=0, vmax=max_number, cmap='Reds', yticklabels=y_label,xticklabels=x_label)

# 绘制标签

plt.xlabel('x label', labelpad=15)
plt.title("Aerial Image")
plt.ylabel('y label', labelpad=20)

plt.show()
